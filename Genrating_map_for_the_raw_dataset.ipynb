# %%
import pandas as pd
pd.set_option("display.max_rows", None)
df = pd.read_csv('kijiji.csv')

# %%
import plotly.express as px
import pandas as pd



fig = px.scatter_mapbox(df,
                        lat="Latitude",
                        lon="Longitude",
                        hover_name="Price",
                        hover_data=["Size", "Bedrooms","Bathrooms","Heat","Hydro","Water","Type","Agreement Type"],
                        )

fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d506e751-c4bc-4777-a0d8-9eef2cbda24c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d506e751-c4bc-4777-a0d8-9eef2cbda24c")) {                    Plotly.newPlot(                        "d506e751-c4bc-4777-a0d8-9eef2cbda24c",                        [{"customdata":[["950","Bedrooms: 2","Bathrooms: 1","Y","N","Y","Apartment","1 Year"],["780","Bedrooms: 2","Bathrooms: 1","N","N","Y","Apartment","1 Year"],["2,200","Bedrooms: 3","Bathrooms: 2.5","Y","N","Y","House","1 Year"],["900","Bedrooms: 2","Bathrooms: 1.5","N","N","Y","House","1 Year"],["1,400","Bedrooms: 2 + Den","Bathrooms: 3","Y","N","Y","House","1 Year"],["850","Bedrooms: 1","Bathrooms: 1","Y","Y","Y","Apartment","1 Year"],["600","Bedrooms: 1","Bathrooms: 1","N","N","Y","Apartment","1 Year"],["1,200","Bedrooms: 2","Bathrooms: 2","N","N","Y","House","1 Year"],["1,466","Bedrooms: 2 + Den","Bathrooms: 2","N","N","N","Townhouse","1 Year"],["1,950","Bedrooms: 2","Bathrooms: 2","N","N","N","House","1 Year"],["900","Bedrooms: 2","Bathrooms: 1","N","N","Y","Apartment","1 Year"],["800","Bedrooms: 1","Bathrooms: 1","N","N","Y","Apartment","1 Year"],["500","Bedrooms: 2","Bathrooms: 1","N","N","Y","Apartment","1 Year"],["900","Bedrooms: 2","Bathrooms: 1","N","N","Y","Apartment","1 Year"],["1,200","Bedrooms: 2","Bathrooms: 1","N","N","Y","Apartment","1 Year"],["1,000","Bedrooms: 3","Bathrooms: 1","N","N","N","Apartment","1 Year"],["440","Bedrooms: 1","Bathrooms: 1","N","N","Y","Apartment","1 Year"],["1,500","Bedrooms: 2","Bathrooms: 1","N","N","N","Duplex\u002fTriplex","1 Year"],["2,300","Bedrooms: 4","Bathrooms: 2","N","N","N","House","1 Year"],["1,000","Bedrooms: 1","Bathrooms: 1","Y","N","Y","Duplex\u002fTriplex","1 Year"],["900","Bedrooms: 4","Bathrooms: 2","N","N","Y","House","1 Year"],["2,250","Bedrooms: 5+","Bathrooms: 2","N","N","N","House","1 Year"],["300","Bedrooms: 1","Bathrooms: 1","Y","Y","Y","Apartment","1 Year"],["1,100","Bedrooms: 2","Bathrooms: 1","N","N","N","Basement","1 Year"],["1,000","Bedrooms: 1","Bathrooms: 1","N","N","N","Condo","1 Year"],["1","Bedrooms: 3","Bathrooms: 1","Y","Y","Y","Apartment","1 Year"],["1,000","Bedrooms: 3","Bathrooms: 2","N","N","N","House","Month-to-month"],["1,200","Bedrooms: 2","Bathrooms: 2","N","N","N","House","1 Year"],["1,000","Bedrooms: 4","Bathrooms: 2","N","N","N","House","1 Year"],[null,"Bedrooms: 2","Bathrooms: 1","Y","N","Y","Apartment","1 Year"],["1,300","Bedrooms: 3 + Den","Bathrooms: 1","N","N","Y","Apartment","1 Year"],["695","Bedrooms: Bachelor\u002fStudio","Bathrooms: 1","Y","N","Y","Apartment","1 Year"],["460","Bedrooms: Bachelor\u002fStudio","Bathrooms: 1","Y","N","Y","Apartment","1 Year"],["628","Bedrooms: 1","Bathrooms: 1","Y","N","Y","Apartment","1 Year"],["1,000","Bedrooms: 4","Bathrooms: 2","N","N","Y","Duplex\u002fTriplex","1 Year"],["785","Bedrooms: 2","Bathrooms: 1","Y","N","Y","Apartment","1 Year"],["1,000","Bedrooms: 2","Bathrooms: 1","N","N","Y","House","1 Year"],["1,250","Bedrooms: 5+","Bathrooms: 2","N","N","N","House","1 Year"],[null,"Bedrooms: 3","Bathrooms: 1.5","Y","N","Y","Apartment","1 Year"],[null,"Bedrooms: 2","Bathrooms: 1","Y","N","Y","Apartment","1 Year"],["700","Bedrooms: 2","Bathrooms: 1","N","N","Y","Duplex\u002fTriplex","1 Year"],["790","Bedrooms: 2","Bathrooms: 1","Y","Y","N","Apartment","Month-to-month"],["450","Bedrooms: 1","Bathrooms: 1","Y","Y","Y","Apartment","Month-to-month"],["1,100","Bedrooms: 3","Bathrooms: 1.5","N","N","Y","Apartment","1 Year"],[null,"Bedrooms: 3","Bathrooms: 2","N","N","N","House","1 Year"],[null,"Bedrooms: 3","Bathrooms: 1","N","N","N","Duplex\u002fTriplex","1 Year"],["2,000","Bedrooms: 2 + Den","Bathrooms: 2","N","N","Y","Duplex\u002fTriplex","1 Year"] ...
